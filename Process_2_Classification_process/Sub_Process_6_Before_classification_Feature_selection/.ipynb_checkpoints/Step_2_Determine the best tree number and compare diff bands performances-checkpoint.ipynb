# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

import re

# %% [markdown]
# ##### Read features as dataframes

# %%
year_range = [f'{i}_{i+2}' for i in range(1990,2020,3)]

# %%
region_en = 'xinan'

# %%
# import the points with image values 
feature_df = [pd.read_csv(f'./Data/Training_sample_{region_en}_{year}.csv') for year in year_range]

# merge all pt_with_img and remove unnecessary columns
feature_df = [fe.drop(['system:index','.geo'],axis=1) for fe in feature_df]

# %% [markdown]
# ##### train_test_split and apply randomforest_classifier

# %%
Sample_acc = {}

for year,fe in zip(year_range,feature_df):
    
    # _______________________________Different band combination_______________________________
    
    col_name = ''.join(fe.columns)
    
    # find the spectrum band names
    Spectrum_reg = re.compile(r'(B6_VCID_\d|B\d{1,2}|Landsat_B\d{1,2}|Sentinel_B\d{1,2}A?)')
    Spectrum_reg_bands = Spectrum_reg.findall(col_name)
    
    # find the Mean-nomalized names
    Mean_nomalize_bands = ['NDVI','NDBI','EVI']
    
    # find the Fourire names
    Fourier_reg   = re.compile(r'((EVI|NDBI|NDVI)_(constant|\w{3}_\d))')
    Fourier_bands = [i[0] for i in Fourier_reg.findall(col_name)]
    
    # get the terrain bands
    Terrain_bands = ['DEM','SLOPE']
    
    # get the meterology bands
    Meterology_bands = ['lrad', 'prec', 'pres', 'shum', 'srad', 'temp', 'wind']

    
    #_________________________________Assess the accuracy ______________________________________
    
    bands_in = zip(['Spectrum',
                    'Spectrum_Normalize',
                    'Spectrum_Normalize_Fourier',
                    'Spectrum_Normalize_Fourier_Terrain',
                    'Spectrum_Normalize_Fourier_Terrain_Meterology'],
                   
                   [Spectrum_reg_bands,
                    Spectrum_reg_bands + Mean_nomalize_bands,
                    Spectrum_reg_bands + Mean_nomalize_bands + Fourier_bands,
                    Spectrum_reg_bands + Mean_nomalize_bands + Fourier_bands + Terrain_bands,
                    Spectrum_reg_bands + Mean_nomalize_bands + Fourier_bands + Terrain_bands + Meterology_bands])
    
    # each_year_band_combination[year] =  list(bands_in)
    
    # ________________________Grid search to compare the accuracy under different input bands__________
    
    for band_name, bands_select in bands_in:
        
        # get the X and y
        X_train = fe[bands_select]
        y_train = fe['Built']
        
        # import testing sample
        test_sample = pd.read_csv(f'./Data/Grid_select_{region_en}_{year}.csv')
        test_sample = test_sample.drop(['system:index','.geo'],axis=1)
        # get the X,y value
        X_test = test_sample.drop('Built',1)[bands_select]
        y_test = test_sample['Built']     
        
        
        # _______________________Grid search to compare the accuracy under different trees__________
        
        for tree in range(1,121):

            # perform the RF classification
            RF = RandomForestClassifier(n_estimators=tree,n_jobs=-1)
            RF.fit(X_train,y_train)
            y_pred = RF.predict(X_test)

            # get the accuracy, here get two kinds of accuracy
            acc_test = accuracy_score(y_test,y_pred)

            # add results to the acc_dict
            Sample_acc[(year,band_name,tree)] = [acc_test]

            # print out the process
            print(f'Accuracy calculation of {region_en}_{year}_{band_name}_{tree} finished!')
# Out:
# Accuracy calculation of xinan_1990_1992_Spectrum_1 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_2 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_3 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_4 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_5 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_6 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_7 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_8 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_9 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_10 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_11 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_12 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_13 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_14 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_15 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_16 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_17 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_18 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_19 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_20 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_21 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_22 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_23 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_24 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_25 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_26 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_27 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_28 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_29 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_30 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_31 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_32 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_33 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_34 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_35 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_36 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_37 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_38 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_39 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_40 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_41 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_42 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_43 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_44 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_45 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_46 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_47 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_48 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_49 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_50 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_51 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_52 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_53 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_54 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_55 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_56 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_57 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_58 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_59 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_60 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_61 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_62 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_63 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_64 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_65 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_66 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_67 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_68 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_69 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_70 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_71 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_72 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_73 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_74 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_75 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_76 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_77 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_78 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_79 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_80 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_81 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_82 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_83 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_84 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_85 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_86 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_87 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_88 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_89 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_90 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_91 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_92 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_93 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_94 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_95 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_96 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_97 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_98 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_99 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_100 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_101 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_102 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_103 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_104 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_105 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_106 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_107 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_108 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_109 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_110 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_111 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_112 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_113 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_114 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_115 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_116 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_117 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_118 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_119 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_120 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_1 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_2 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_3 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_4 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_5 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_6 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_7 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_8 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_9 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_10 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_11 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_12 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_13 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_14 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_15 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_16 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_17 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_18 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_19 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_20 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_21 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_22 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_23 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_24 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_25 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_26 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_27 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_28 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_29 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_30 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_31 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_32 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_33 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_34 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_35 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_36 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_37 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_38 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_39 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_40 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_41 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_42 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_43 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_44 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_45 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_46 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_47 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_48 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_49 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_50 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_51 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_52 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_53 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_54 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_55 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_56 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_57 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_58 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_59 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_60 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_61 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_62 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_63 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_64 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_65 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_66 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_67 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_68 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_69 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_70 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_71 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_72 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_73 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_74 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_75 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_76 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_77 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_78 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_79 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_80 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_81 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_82 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_83 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_84 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_85 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_86 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_87 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_88 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_89 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_90 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_91 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_92 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_93 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_94 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_95 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_96 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_97 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_98 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_99 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_100 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_101 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_102 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_103 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_104 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_105 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_106 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_107 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_108 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_109 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_110 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_111 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_112 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_113 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_114 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_115 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_116 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_117 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_118 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_119 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_120 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_1 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_2 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_3 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_4 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_5 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_6 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_7 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_8 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_9 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_10 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_11 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_12 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_13 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_14 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_15 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_16 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_17 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_18 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_19 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_20 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_21 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_22 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_23 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_24 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_25 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_26 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_27 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_28 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_29 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_30 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_31 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_32 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_33 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_34 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_35 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_36 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_37 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_38 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_39 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_40 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_41 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_42 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_43 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_44 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_45 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_46 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_47 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_48 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_49 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_50 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_51 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_52 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_53 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_54 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_55 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_56 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_57 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_58 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_59 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_60 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_61 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_62 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_63 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_64 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_65 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_66 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_67 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_68 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_69 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_70 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_71 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_72 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_73 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_74 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_75 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_76 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_77 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_78 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_79 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_80 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_81 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_82 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_83 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_84 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_85 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_86 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_87 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_88 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_89 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_90 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_91 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_92 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_93 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_94 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_95 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_96 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_97 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_98 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_99 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_100 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_101 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_102 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_103 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_104 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_105 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_106 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_107 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_108 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_109 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_110 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_111 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_112 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_113 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_114 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_115 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_116 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_117 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_118 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_119 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_120 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_1 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_2 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_3 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_4 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_5 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_6 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_7 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_8 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_9 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_10 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_11 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_12 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_13 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_14 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_15 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_16 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_17 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_18 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_19 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_20 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_21 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_22 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_23 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_24 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_25 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_26 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_27 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_28 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_29 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_30 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_31 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_32 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_33 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_34 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_35 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_36 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_37 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_38 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_39 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_40 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_41 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_42 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_43 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_44 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_45 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_46 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_47 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_48 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_49 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_50 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_51 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_52 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_53 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_54 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_55 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_56 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_57 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_58 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_59 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_60 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_61 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_62 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_63 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_64 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_65 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_66 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_67 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_68 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_69 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_70 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_71 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_72 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_73 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_74 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_75 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_76 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_77 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_78 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_79 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_80 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_81 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_82 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_83 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_84 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_85 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_86 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_87 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_88 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_89 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_90 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_91 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_92 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_93 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_94 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_95 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_96 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_97 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_98 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_99 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_100 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_101 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_102 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_103 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_104 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_105 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_106 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_107 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_108 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_109 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_110 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_111 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_112 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_113 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_114 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_115 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_116 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_117 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_118 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_119 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_120 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_1 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_2 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_3 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_4 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_5 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_6 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_7 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_8 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_9 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_10 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_11 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_12 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_13 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_14 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_15 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_16 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_17 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_18 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_19 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_20 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_21 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_22 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_23 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_24 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_25 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_26 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_27 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_28 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_29 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_30 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_31 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_32 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_33 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_34 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_35 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_36 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_37 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_38 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_39 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_40 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_41 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_42 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_43 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_44 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_45 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_46 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_47 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_48 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_49 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_50 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_51 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_52 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_53 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_54 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_55 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_56 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_57 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_58 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_59 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_60 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_61 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_62 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_63 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_64 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_65 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_66 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_67 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_68 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_69 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_70 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_71 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_72 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_73 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_74 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_75 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_76 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_77 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_78 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_79 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_80 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_81 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_82 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_83 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_84 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_85 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_86 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_87 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_88 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_89 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_90 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_91 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_92 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_93 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_94 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_95 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_96 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_97 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_98 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_99 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_100 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_101 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_102 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_103 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_104 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_105 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_106 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_107 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_108 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_109 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_110 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_111 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_112 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_113 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_114 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_115 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_116 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_117 finished!
# Accuracy calculation of xinan_1990_1992_Spectrum_Normalize_Fourier_Terrain_Meterology_118 finished!
# ...
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_75 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_76 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_77 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_78 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_79 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_80 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_81 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_82 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_83 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_84 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_85 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_86 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_87 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_88 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_89 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_90 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_91 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_92 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_93 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_94 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_95 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_96 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_97 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_98 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_99 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_100 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_101 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_102 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_103 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_104 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_105 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_106 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_107 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_108 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_109 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_110 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_111 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_112 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_113 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_114 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_115 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_116 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_117 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_118 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_119 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_120 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_1 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_2 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_3 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_4 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_5 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_6 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_7 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_8 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_9 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_10 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_11 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_12 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_13 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_14 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_15 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_16 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_17 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_18 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_19 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_20 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_21 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_22 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_23 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_24 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_25 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_26 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_27 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_28 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_29 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_30 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_31 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_32 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_33 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_34 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_35 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_36 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_37 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_38 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_39 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_40 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_41 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_42 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_43 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_44 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_45 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_46 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_47 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_48 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_49 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_50 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_51 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_52 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_53 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_54 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_55 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_56 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_57 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_58 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_59 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_60 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_61 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_62 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_63 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_64 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_65 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_66 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_67 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_68 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_69 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_70 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_71 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_72 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_73 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_74 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_75 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_76 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_77 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_78 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_79 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_80 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_81 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_82 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_83 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_84 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_85 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_86 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_87 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_88 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_89 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_90 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_91 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_92 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_93 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_94 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_95 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_96 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_97 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_98 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_99 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_100 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_101 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_102 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_103 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_104 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_105 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_106 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_107 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_108 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_109 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_110 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_111 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_112 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_113 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_114 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_115 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_116 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_117 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_118 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_119 finished!
# Accuracy calculation of xinan_2017_2019_Spectrum_Normalize_Fourier_Terrain_Meterology_120 finished!

# %%
pd.DataFrame(Sample_acc).T
# Out:
#                                                                     0
# 1990_1992 Spectrum                                      1    0.791798
#                                                         2    0.802839
#                                                         3    0.837539
#                                                         4    0.831230
#                                                         5    0.840694
# ...                                                               ...
# 2017_2019 Spectrum_Normalize_Fourier_Terrain_Meterology 116  0.905363
#                                                         117  0.899054
#                                                         118  0.900631
#                                                         119  0.899054
#                                                         120  0.900631
#
# [6000 rows x 1 columns]

# %% [markdown]
# ##### Save the grid_acc  to disk

# %%
grid_acc = pd.DataFrame(Sample_acc).T
grid_acc.reset_index(inplace=True)
grid_acc.columns = ['Year','In_Bands','Tree','Accuracy']
grid_acc.to_csv(f'./Result/Grid_acc_tree_{region_en}.csv',index = False)

# load the grid_acc
grid_acc = pd.read_csv(f'./Result/Grid_acc_tree_{region_en}.csv')
grid_acc['Year'] = grid_acc['Year'].astype('category')

# %%
grid_acc
# Out:
#            Year                                       In_Bands  Tree  Accuracy
# 0     1990_1992                                       Spectrum     1  0.791798
# 1     1990_1992                                       Spectrum     2  0.802839
# 2     1990_1992                                       Spectrum     3  0.837539
# 3     1990_1992                                       Spectrum     4  0.831230
# 4     1990_1992                                       Spectrum     5  0.840694
# ...         ...                                            ...   ...       ...
# 5995  2017_2019  Spectrum_Normalize_Fourier_Terrain_Meterology   116  0.905363
# 5996  2017_2019  Spectrum_Normalize_Fourier_Terrain_Meterology   117  0.899054
# 5997  2017_2019  Spectrum_Normalize_Fourier_Terrain_Meterology   118  0.900631
# 5998  2017_2019  Spectrum_Normalize_Fourier_Terrain_Meterology   119  0.899054
# 5999  2017_2019  Spectrum_Normalize_Fourier_Terrain_Meterology   120  0.900631
#
# [6000 rows x 4 columns]

# %% [markdown]
# ##### Observe that the tree number of 100 is enough for classification

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data = grid_acc[grid_acc['In_Bands']=='Spectrum_Normalize_Fourier_Terrain_Meterology'],
             x='Tree',
             y='Accuracy')

# %% [markdown]
# ##### Observe that the Fourier bands significant increases the accuracy

# %%
# get the accuracy with the tree number of 100
Acc_tree_100 = grid_acc[grid_acc['Tree'] == 100]

# %%
Acc_tree_100
# Out:
#            Year                                       In_Bands  Tree  Accuracy
# 99    1990_1992                                       Spectrum   100  0.845426
# 219   1990_1992                             Spectrum_Normalize   100  0.847003
# 339   1990_1992                     Spectrum_Normalize_Fourier   100  0.823344
# 459   1990_1992             Spectrum_Normalize_Fourier_Terrain   100  0.843849
# 579   1990_1992  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.843849
# 699   1993_1995                                       Spectrum   100  0.843849
# 819   1993_1995                             Spectrum_Normalize   100  0.847003
# 939   1993_1995                     Spectrum_Normalize_Fourier   100  0.847003
# 1059  1993_1995             Spectrum_Normalize_Fourier_Terrain   100  0.847003
# 1179  1993_1995  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.842271
# 1299  1996_1998                                       Spectrum   100  0.837539
# 1419  1996_1998                             Spectrum_Normalize   100  0.854890
# 1539  1996_1998                     Spectrum_Normalize_Fourier   100  0.861199
# 1659  1996_1998             Spectrum_Normalize_Fourier_Terrain   100  0.861199
# 1779  1996_1998  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.862776
# 1899  1999_2001                                       Spectrum   100  0.850318
# 2019  1999_2001                             Spectrum_Normalize   100  0.863057
# 2139  1999_2001                     Spectrum_Normalize_Fourier   100  0.859873
# 2259  1999_2001             Spectrum_Normalize_Fourier_Terrain   100  0.869427
# 2379  1999_2001  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.851911
# 2499  2002_2004                                       Spectrum   100  0.821767
# 2619  2002_2004                             Spectrum_Normalize   100  0.842271
# 2739  2002_2004                     Spectrum_Normalize_Fourier   100  0.840694
# 2859  2002_2004             Spectrum_Normalize_Fourier_Terrain   100  0.837539
# 2979  2002_2004  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.845426
# 3099  2005_2007                                       Spectrum   100  0.839117
# 3219  2005_2007                             Spectrum_Normalize   100  0.851735
# 3339  2005_2007                     Spectrum_Normalize_Fourier   100  0.865931
# 3459  2005_2007             Spectrum_Normalize_Fourier_Terrain   100  0.858044
# 3579  2005_2007  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.853312
# 3699  2008_2010                                       Spectrum   100  0.856467
# 3819  2008_2010                             Spectrum_Normalize   100  0.875394
# 3939  2008_2010                     Spectrum_Normalize_Fourier   100  0.869085
# 4059  2008_2010             Spectrum_Normalize_Fourier_Terrain   100  0.864353
# 4179  2008_2010  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.858044
# 4299  2011_2013                                       Spectrum   100  0.872240
# 4419  2011_2013                             Spectrum_Normalize   100  0.875394
# 4539  2011_2013                     Spectrum_Normalize_Fourier   100  0.867508
# 4659  2011_2013             Spectrum_Normalize_Fourier_Terrain   100  0.865931
# 4779  2011_2013  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.872240
# 4899  2014_2016                                       Spectrum   100  0.886435
# 5019  2014_2016                             Spectrum_Normalize   100  0.891167
# 5139  2014_2016                     Spectrum_Normalize_Fourier   100  0.892744
# 5259  2014_2016             Spectrum_Normalize_Fourier_Terrain   100  0.892744
# 5379  2014_2016  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.897476
# 5499  2017_2019                                       Spectrum   100  0.881703
# 5619  2017_2019                             Spectrum_Normalize   100  0.888013
# 5739  2017_2019                     Spectrum_Normalize_Fourier   100  0.891167
# 5859  2017_2019             Spectrum_Normalize_Fourier_Terrain   100  0.899054
# 5979  2017_2019  Spectrum_Normalize_Fourier_Terrain_Meterology   100  0.902208

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data = Acc_tree_100,
             x='Year',
             y='Accuracy',
             hue = 'In_Bands')

# %% [markdown]
# ##### Just for fun: Use ANN(tf) to construct to classification moedl

# %%
# get one df for trying
fe = feature_df[-1]

# get the X and y
X = fe.drop('Built',1)
y = fe['Built']

# train/test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# reshape the y values 
y_train = y_train.values.reshape([-1,1])
y_test = y_test.values.reshape([-1,1])

# %%
# scale the X values 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit_transform(X_train)

X_train = scaler.transform(X_train)
X_test  = scaler.transform(X_test)

# %%
# construct the ANN model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
# built layers 
model = Sequential()

model.add(Dense(20,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(5,activation='relu'))
model.add(Dense(2,activation='relu'))

model.add(Dense(1,activation = 'sigmoid'))

model.compile(optimizer='adam',loss = 'binary_crossentropy')

# %%
# fit the model with X and y
model.fit(x=X_train,y=y_train,epochs=100,validation_data=(X_test,y_test))
# Out:
# Train on 6732 samples, validate on 3317 samples
# Epoch 1/100
# 6732/6732 [==============================] - 1s 216us/sample - loss: 0.6044 - val_loss: 0.4562
# Epoch 2/100
# 6732/6732 [==============================] - 0s 50us/sample - loss: 0.3989 - val_loss: 0.3630
# Epoch 3/100
# 6732/6732 [==============================] - 0s 54us/sample - loss: 0.3424 - val_loss: 0.3296
# Epoch 4/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.3092 - val_loss: 0.3011
# Epoch 5/100
# 6732/6732 [==============================] - 0s 53us/sample - loss: 0.2837 - val_loss: 0.2805
# Epoch 6/100
# 6732/6732 [==============================] - 0s 51us/sample - loss: 0.2639 - val_loss: 0.2818
# Epoch 7/100
# 6732/6732 [==============================] - 0s 52us/sample - loss: 0.2495 - val_loss: 0.2578
# Epoch 8/100
# 6732/6732 [==============================] - 0s 52us/sample - loss: 0.2343 - val_loss: 0.2570
# Epoch 9/100
# 6732/6732 [==============================] - 0s 52us/sample - loss: 0.2230 - val_loss: 0.2375
# Epoch 10/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.2155 - val_loss: 0.2310
# Epoch 11/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.2103 - val_loss: 0.2182
# Epoch 12/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1948 - val_loss: 0.2026
# Epoch 13/100
# 6732/6732 [==============================] - 0s 48us/sample - loss: 0.1859 - val_loss: 0.1910
# Epoch 14/100
# 6732/6732 [==============================] - 0s 51us/sample - loss: 0.1786 - val_loss: 0.1803
# Epoch 15/100
# 6732/6732 [==============================] - 0s 52us/sample - loss: 0.1744 - val_loss: 0.1776
# Epoch 16/100
# 6732/6732 [==============================] - 0s 52us/sample - loss: 0.1654 - val_loss: 0.1690
# Epoch 17/100
# 6732/6732 [==============================] - 0s 54us/sample - loss: 0.1582 - val_loss: 0.1641
# Epoch 18/100
# 6732/6732 [==============================] - 0s 53us/sample - loss: 0.1540 - val_loss: 0.1628
# Epoch 19/100
# 6732/6732 [==============================] - 0s 52us/sample - loss: 0.1505 - val_loss: 0.1567
# Epoch 20/100
# 6732/6732 [==============================] - 0s 52us/sample - loss: 0.1457 - val_loss: 0.1603
# Epoch 21/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1414 - val_loss: 0.1500
# Epoch 22/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.1390 - val_loss: 0.1544
# Epoch 23/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.1378 - val_loss: 0.1529
# Epoch 24/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1382 - val_loss: 0.1524
# Epoch 25/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1320 - val_loss: 0.1669
# Epoch 26/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.1297 - val_loss: 0.1388
# Epoch 27/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1311 - val_loss: 0.1450
# Epoch 28/100
# 6732/6732 [==============================] - 0s 62us/sample - loss: 0.1265 - val_loss: 0.1379
# Epoch 29/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1265 - val_loss: 0.1363
# Epoch 30/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1235 - val_loss: 0.1359
# Epoch 31/100
# 6732/6732 [==============================] - 0s 69us/sample - loss: 0.1221 - val_loss: 0.1324
# Epoch 32/100
# 6732/6732 [==============================] - 0s 60us/sample - loss: 0.1219 - val_loss: 0.1325
# Epoch 33/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.1217 - val_loss: 0.1361
# Epoch 34/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1199 - val_loss: 0.1305
# Epoch 35/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1183 - val_loss: 0.1309
# Epoch 36/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.1244 - val_loss: 0.1494
# Epoch 37/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1168 - val_loss: 0.1298
# Epoch 38/100
# 6732/6732 [==============================] - 0s 60us/sample - loss: 0.1175 - val_loss: 0.1286
# Epoch 39/100
# 6732/6732 [==============================] - 0s 61us/sample - loss: 0.1157 - val_loss: 0.1346
# Epoch 40/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.1157 - val_loss: 0.1296
# Epoch 41/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.1144 - val_loss: 0.1264
# Epoch 42/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.1124 - val_loss: 0.1306
# Epoch 43/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1124 - val_loss: 0.1315
# Epoch 44/100
# 6732/6732 [==============================] - 0s 62us/sample - loss: 0.1120 - val_loss: 0.1263
# Epoch 45/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1133 - val_loss: 0.1431
# Epoch 46/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1101 - val_loss: 0.1483
# Epoch 47/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.1097 - val_loss: 0.1249
# Epoch 48/100
# 6732/6732 [==============================] - 0s 54us/sample - loss: 0.1118 - val_loss: 0.1279
# Epoch 49/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.1119 - val_loss: 0.1321
# Epoch 50/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1071 - val_loss: 0.1240
# Epoch 51/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1072 - val_loss: 0.1282
# Epoch 52/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1086 - val_loss: 0.1291
# Epoch 53/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.1061 - val_loss: 0.1220
# Epoch 54/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.1061 - val_loss: 0.1244
# Epoch 55/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.1064 - val_loss: 0.1221
# Epoch 56/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1067 - val_loss: 0.1228
# Epoch 57/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.1081 - val_loss: 0.1239
# Epoch 58/100
# 6732/6732 [==============================] - 0s 62us/sample - loss: 0.1060 - val_loss: 0.1216
# Epoch 59/100
# 6732/6732 [==============================] - 0s 62us/sample - loss: 0.1071 - val_loss: 0.1225
# Epoch 60/100
# 6732/6732 [==============================] - 0s 60us/sample - loss: 0.1053 - val_loss: 0.1263
# Epoch 61/100
# 6732/6732 [==============================] - 0s 72us/sample - loss: 0.1051 - val_loss: 0.1192
# Epoch 62/100
# 6732/6732 [==============================] - 0s 66us/sample - loss: 0.1037 - val_loss: 0.1234
# Epoch 63/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.1030 - val_loss: 0.1484
# Epoch 64/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.1033 - val_loss: 0.1228
# Epoch 65/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.1027 - val_loss: 0.1191
# Epoch 66/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1013 - val_loss: 0.1347
# Epoch 67/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1043 - val_loss: 0.1205
# Epoch 68/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.0988 - val_loss: 0.1183
# Epoch 69/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1007 - val_loss: 0.1187
# Epoch 70/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.0988 - val_loss: 0.1178
# Epoch 71/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.1037 - val_loss: 0.1249
# Epoch 72/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1011 - val_loss: 0.1242
# Epoch 73/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.0984 - val_loss: 0.1209
# Epoch 74/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.1025 - val_loss: 0.1153
# Epoch 75/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.0989 - val_loss: 0.1256
# Epoch 76/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.0992 - val_loss: 0.1257
# Epoch 77/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.0994 - val_loss: 0.1171
# Epoch 78/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.0977 - val_loss: 0.1289
# Epoch 79/100
# 6732/6732 [==============================] - 1s 78us/sample - loss: 0.0987 - val_loss: 0.1185
# Epoch 80/100
# 6732/6732 [==============================] - 0s 60us/sample - loss: 0.0981 - val_loss: 0.1149
# Epoch 81/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.0967 - val_loss: 0.1155
# Epoch 82/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.0955 - val_loss: 0.1169
# Epoch 83/100
# 6732/6732 [==============================] - 0s 60us/sample - loss: 0.0975 - val_loss: 0.1159
# Epoch 84/100
# 6732/6732 [==============================] - 0s 60us/sample - loss: 0.0964 - val_loss: 0.1175
# Epoch 85/100
# 6732/6732 [==============================] - 0s 64us/sample - loss: 0.0946 - val_loss: 0.1215
# Epoch 86/100
# 6732/6732 [==============================] - 0s 59us/sample - loss: 0.0970 - val_loss: 0.1167
# Epoch 87/100
# 6732/6732 [==============================] - 0s 62us/sample - loss: 0.0964 - val_loss: 0.1134
# Epoch 88/100
# 6732/6732 [==============================] - 0s 58us/sample - loss: 0.0932 - val_loss: 0.1158
# Epoch 89/100
# 6732/6732 [==============================] - 0s 57us/sample - loss: 0.0939 - val_loss: 0.1218
# Epoch 90/100
# 6732/6732 [==============================] - 0s 63us/sample - loss: 0.0974 - val_loss: 0.1158
# Epoch 91/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.0950 - val_loss: 0.1158
# Epoch 92/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.0960 - val_loss: 0.1209
# Epoch 93/100
# 6732/6732 [==============================] - 0s 55us/sample - loss: 0.0947 - val_loss: 0.1543
# Epoch 94/100
# 6732/6732 [==============================] - 0s 54us/sample - loss: 0.0951 - val_loss: 0.1134
# Epoch 95/100
# 6732/6732 [==============================] - 0s 53us/sample - loss: 0.0936 - val_loss: 0.1139
# Epoch 96/100
# 6732/6732 [==============================] - 0s 54us/sample - loss: 0.0914 - val_loss: 0.1135
# Epoch 97/100
# 6732/6732 [==============================] - 0s 54us/sample - loss: 0.0913 - val_loss: 0.1157
# Epoch 98/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.0920 - val_loss: 0.1418
# Epoch 99/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.0929 - val_loss: 0.1220
# Epoch 100/100
# 6732/6732 [==============================] - 0s 56us/sample - loss: 0.0939 - val_loss: 0.1242

# %%
# plot the losses
losses = pd.DataFrame(model.history.history)
losses.plot()

# %%
# let's see the performance of the modle
from sklearn.metrics import classification_report,confusion_matrix
pred = model.predict_classes(X_test)

# %%
# print the classification report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96      1646
#            1       0.97      0.94      0.96      1671
#
#     accuracy                           0.96      3317
#    macro avg       0.96      0.96      0.96      3317
# weighted avg       0.96      0.96      0.96      3317

# %%
# print the confusin matrix
print(confusion_matrix(y_test,pred))
# Out:
# [[1603   43]
#  [  97 1574]]
