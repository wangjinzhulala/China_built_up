# %%
import ee
import datetime
import os
import itertools
import sys
import re

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import geemap

import subprocess
from subprocess import PIPE
import ast

# %%
ee.Initialize()

# %%
# append upper folder into sys-path during run time so we can
# import our own moduls
sys.path.append('../../')

# %%
from BackGround_modules.Class_2_Classify_Fourier_Img   import Classification
from BackGround_modules.Class_3_Calculate_the_accuracy import Accuracy_assesment

# %% [markdown]
# ##### Prepare basic parameters

# %%
region_cn = '中南'
region_en = 'zhongnan'

# %%
# define the years to be classified
year_name  = [f'{i}_{i+2}' for i in range(1990,2020,3)]

# define the number of total periods
num_invarient = 10

# %%
year_name
# Out:
# ['1990_1992',
#  '1993_1995',
#  '1996_1998',
#  '1999_2001',
#  '2002_2004',
#  '2005_2007',
#  '2008_2010',
#  '2011_2013',
#  '2014_2016',
#  '2017_2019']

# %%
# import north_china_plain boundary
Region =  ee.FeatureCollection("users/wangjinzhulala/China_built_up/01_Boundary_shp/China_zone")\
            .filterMetadata('NAME1','equals',region_cn)

# %%
# Define the path to Sample_pt
sample_img_path = f'users/wangjinzhulala/China_built_up/04_sample_train_test_split'

# %%
export_path = 'users/wangjinzhulala/China_built_up/05_primary_classification'

# %% [markdown]
# ##### Fetch all imgs

# %%
# read all asset_df into a list
asset_list = [pd.read_csv(f'../../File_trainsition/gee_asset_china/{str(i).zfill(2)}_path.csv') 
              for i in range(1,22)]

# %%
# concate all asset_df into one df
asset_df = pd.concat(asset_list)

# %%
asset_df.sort_values(['region','type','year'],inplace=True)

# %%
asset_df
# Out:
#          year           type  \
# 0   1990_1992        Fourier
# 1   1993_1995        Fourier
# 2   1996_1998        Fourier
# 3   1999_2001        Fourier
# 4   2002_2004        Fourier
# ..        ...            ...
# 10  2005_2007  NDVI_NDBI_EVI
# 11  2008_2010  NDVI_NDBI_EVI
# 12  2011_2013  NDVI_NDBI_EVI
# 13  2014_2016  NDVI_NDBI_EVI
# 14  2017_2019  NDVI_NDBI_EVI
#
#                                                  path    region
# 0   projects/earthengine-legacy/assets/users/bthom...   dongbei
# 1   projects/earthengine-legacy/assets/users/bthom...   dongbei
# 2   projects/earthengine-legacy/assets/users/bthom...   dongbei
# 3   projects/earthengine-legacy/assets/users/bthom...   dongbei
# 4   projects/earthengine-legacy/assets/users/bthom...   dongbei
# ..                                                ...       ...
# 10  projects/earthengine-legacy/assets/users/fhane...  zhongnan
# 11  projects/earthengine-legacy/assets/users/fhane...  zhongnan
# 12  projects/earthengine-legacy/assets/users/fhane...  zhongnan
# 13  projects/earthengine-legacy/assets/users/fhane...  zhongnan
# 14  projects/earthengine-legacy/assets/users/fhane...  zhongnan
#
# [180 rows x 4 columns]

# %% [markdown]
# ##### Prepare input_image for classification

# %% [markdown]
# Some additional treatment for the last two periods of Landsat and Sentinel imgs

# %%
# import Landsat img
Landsat_df = asset_df[(asset_df['type']=='Landsat_cloud_free')&(asset_df['region']==region_en)]
Landsat_img = [ee.Image(i) for i in  Landsat_df['path'].values]

# %%
# import Fourier img   
Fourier_df  = asset_df[(asset_df['type']=='Fourier')&(asset_df['region']==region_en)]
Fourier_img = [ee.Image(i) for i in  Fourier_df['path'].values]

# %%
# import Normalized img   
Normalized_df  = asset_df[(asset_df['type']=='NDVI_NDBI_EVI')&(asset_df['region']==region_en)]
Normalized_img = [ee.Image(i) for i in  Normalized_df['path'].values]

# %%
# prepare the climate data
Climate_mean = [ee.Image(f"users/China_bulit/01_Data_preparation/Climate_Mean_{year}")
                for year in year_name]

# %%
# Import DEM/SLOPE Img
DEM   = [ee.Image("USGS/SRTMGL1_003").rename('DEM')] * num_invarient
SLOPE = [ee.Terrain.slope(DEM).rename('SLOPE')] * num_invarient

# %%
# stack all Imput_Img together
Stack_img = [ee.Image(img) for img in zip(Landsat_img,
                                           Fourier_img,
                                           Normalized_img,
                                           Climate_mean,
                                           DEM,
                                           SLOPE)]

# %% [markdown]
# ################ Some extra export for fig making, not useful for this classification ################

# %%
# # get the observation rectagles
# # clip = ee.FeatureCollection("users/wangjinzhulala/North_China_Plain_Python/Boundary_shp/Observation_Rectangle_Full")

# # loop through each year to get target imgs
# for year,img in zip(year_name,Stack_img):
    
#     # get imgs
#     Fourier = img.select(['NDBI_cos_1','EVI_sin_2','NDVI_sin_2']).clip(clip)
#     Normalized = img.select(['Mean_NDVI','Mean_NDBI','Mean_EVI']).clip(clip)
    
#     # Landsat 8 has different flase color composite compare to 5/7
#     if int(year[-4:]) <= 2013 :
#         False_color = img.select(['B4','B3','B2']).clip(clip)
#     else:
#         False_color = img.select(['Landsat_B5','Landsat_B4','Landsat_B3']).clip(clip)
        
        
#     # stack imgs together for export    
#     imgs = [Fourier,Normalized,False_color] 
#     img_names = ['Fourier','Normalized','False_color'] 
    
#     # export to CloudStorage
#     for img,name in zip(imgs,img_names):
        
#         # construcnt img name for export
#         img_name = f'{name}_{year}'
        
#         # export
#         task = ee.batch.Export.image.toCloudStorage(image = img,
#                                                     description=img_name,
#                                                     bucket='north_china_plain',
#                                                     fileNamePrefix=img_name,
#                                                     region=clip,
#                                                     scale=30,
#                                                     maxPixels=int(1e13),
#                                                     skipEmptyTiles=True) 
    
#         task.start()
        
#         # print out the process.
#         print(f'Exporting {img_name} successful!')

# %% [markdown]
# ##### Prepare input sample points

# %%
# Get the training sample
Training_sample = [ee.FeatureCollection(f"{sample_img_path}/Training_sample_{region_en}_{year}")
                   for year in year_name]

# %% [markdown]
# ##### Stack input_img and input_sample together

# %%
# first put all inputs together
stack_year   = year_name
stack_img    = Stack_img 
stack_sample = Training_sample 

# stack all ingredients together
Stack_img_sample = list(zip(stack_year,stack_img,stack_sample))

# %% [markdown]
# #### Create the classification instances

# %%
# import the inbands-combination 
in_band_df = pd.read_csv('../Sub_Process_7_Before_classification_Feature_selection/Result/In_bands_combination.csv')

# selections for in-band combination
in_band_selection =[#'Spectrum',
                    #'Spectrum_Normalize',
                    #'Spectrum_Normalize_Fourier',
                    #'Spectrum_Normalize_Fourier_Terrain',
                    'Spectrum_Normalize_Fourier_Terrain_Meterology']

# %%
# A three-layer iteration to loopthrough [inbands/year/10-randome-split] individualy

Classificatioin_result = []

# The first-layer loop to go througth each inbands
for input_bands in in_band_selection:

    # The second-layer loop to go througth each year-periods
    for i,input_variable in enumerate(Stack_img_sample):
        
        
        # Fetch basic parameters
        classificaiton_tpye = input_bands
        year                = input_variable[0]
        input_img           = input_variable[1]
        sample_pt           = input_variable[2]

        # here determine which bands are involved in the classification
        # because the list is a string represented format, here use ast 
        # module to conver it back to a Python list
        in_features         = ast.literal_eval(in_band_df.at[i,input_bands])
        

        # The third-layer to go through each-randomnes
        for seed in range(10):

            #_______________________________Deploy the random-forest classification______________________
            # Instatiate the class with a name.
            classification = Classification(year_name      = year,
                                            Verified_point = sample_pt,
                                            Input_img      = input_img,
                                            Input_band     = in_features,
                                            Tree_num       = 100,
                                            seed           = seed,
                                            classProperty  = 'Built')


            # Get the classified img
            classified_img = classification.classification_img


            # Get the classified samples
            train_sample_classified = classification.Train_sample_classification
            test_sample_classified  = classification.Test_sample_classification

            #__________________________________Add all classification result into a list____________________________
            Classificatioin_result.append((classificaiton_tpye,year,seed,classified_img,test_sample_classified))

# %%
# convert classificaiton instances into a dataframe
Classification_instances_df =  pd.DataFrame(Classificatioin_result,
                                            columns=['classificaiton_tpye','year','seed','classified_img',
                                                     'test_sample_classified'])
Classification_instances_df
# Out:
#                               classificaiton_tpye       year  seed  \
# 0   Spectrum_Normalize_Fourier_Terrain_Meterology  1990_1992     0
# 1   Spectrum_Normalize_Fourier_Terrain_Meterology  1990_1992     1
# 2   Spectrum_Normalize_Fourier_Terrain_Meterology  1990_1992     2
# 3   Spectrum_Normalize_Fourier_Terrain_Meterology  1990_1992     3
# 4   Spectrum_Normalize_Fourier_Terrain_Meterology  1990_1992     4
# ..                                            ...        ...   ...
# 95  Spectrum_Normalize_Fourier_Terrain_Meterology  2017_2019     5
# 96  Spectrum_Normalize_Fourier_Terrain_Meterology  2017_2019     6
# 97  Spectrum_Normalize_Fourier_Terrain_Meterology  2017_2019     7
# 98  Spectrum_Normalize_Fourier_Terrain_Meterology  2017_2019     8
# 99  Spectrum_Normalize_Fourier_Terrain_Meterology  2017_2019     9
#
#                                        classified_img  \
# 0   ee.Image({\n  "functionInvocationValue": {\n  ...
# 1   ee.Image({\n  "functionInvocationValue": {\n  ...
# 2   ee.Image({\n  "functionInvocationValue": {\n  ...
# 3   ee.Image({\n  "functionInvocationValue": {\n  ...
# 4   ee.Image({\n  "functionInvocationValue": {\n  ...
# ..                                                ...
# 95  ee.Image({\n  "functionInvocationValue": {\n  ...
# 96  ee.Image({\n  "functionInvocationValue": {\n  ...
# 97  ee.Image({\n  "functionInvocationValue": {\n  ...
# 98  ee.Image({\n  "functionInvocationValue": {\n  ...
# 99  ee.Image({\n  "functionInvocationValue": {\n  ...
#
#                                test_sample_classified
# 0   ee.FeatureCollection({\n  "functionInvocationV...
# 1   ee.FeatureCollection({\n  "functionInvocationV...
# 2   ee.FeatureCollection({\n  "functionInvocationV...
# 3   ee.FeatureCollection({\n  "functionInvocationV...
# 4   ee.FeatureCollection({\n  "functionInvocationV...
# ..                                                ...
# 95  ee.FeatureCollection({\n  "functionInvocationV...
# 96  ee.FeatureCollection({\n  "functionInvocationV...
# 97  ee.FeatureCollection({\n  "functionInvocationV...
# 98  ee.FeatureCollection({\n  "functionInvocationV...
# 99  ee.FeatureCollection({\n  "functionInvocationV...
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Add one of the classified img to map

# %%
# define parameters of classification for show in map
bands_in_type = 'Spectrum_Normalize_Fourier_Terrain_Meterology'
year_in       = '2017_2019'


# get the classification img
one = Classification_instances_df[(Classification_instances_df['classificaiton_tpye'] == bands_in_type) &
                                  (Classification_instances_df['year'] == year_in) &
                                  (Classification_instances_df['seed'] == 5)]['classified_img'].values[0]

# %%
# add the selected classification in map
Map = geemap.Map()
Map.add_basemap('HYBRID')
Map.centerObject(Region,6)
Map.addLayer(one,{'min':0,'max':1},'One')
Map
# Out:
# Map(center=[27.33041569106484, 111.63607653815916], controls=(WidgetControl(options=['position'], widget=HBox(…

# %% [markdown]
# ##### Export the classified_img

# %%
for idx,item in Classification_instances_df.iterrows():
     
    Classification_type = item[0]
    year = item[1]
    seed = item[2]
    img  = item[3].toInt8()
    
    
    export_name = f'{Classification_type}_{region_en}_{year}_{seed}'
    
    #export to GEE asset    
    task = ee.batch.Export.image.toAsset(   image          = img,
                                            description    = export_name,
                                            assetId        = f'{export_path}/{export_name}',
                                            region         = Region.geometry().bounds(),
                                            scale          = 30,
                                            maxPixels      = int(1e13)) 
    
    task.start()
    
#     #export to Google Cloud Storage   
#     task = ee.batch.Export.image.toCloudStorage(    image = img,
#                                                     description=export_name,
#                                                     bucket='north_china_plain',
#                                                     fileNamePrefix=export_name,
#                                                     region=Region.geometry().bounds(),
#                                                     scale=30,
#                                                     maxPixels=int(1e13),
#                                                     skipEmptyTiles=True) 
    
#     task.start()
    
    print(f'Exporting {export_name} successful!')
# Out:
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1990_1992_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1993_1995_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1996_1998_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_1999_2001_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2002_2004_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2005_2007_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2008_2010_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2011_2013_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2014_2016_9 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_0 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_1 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_2 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_3 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_4 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_5 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_6 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_7 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_8 successful!
# Exporting Spectrum_Normalize_Fourier_Terrain_Meterology_zhongnan_2017_2019_9 successful!
