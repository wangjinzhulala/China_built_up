# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ##### Define basic parameter

# %%
region_en = 'zhongnan'

# %%
year_range = [f'{i}_{i+2}' for i in range(1990,2020,3)]

# %%
# define the year range
year_start = [i for i in range(1990,2018,3)]
year_end   = [i for i in range(1992,2020,3)]

year_name = [f'{i[0]}_{i[1]}' for i in zip(year_start,year_end)]

# %%
year_name
# Out:
# ['1990_1992',
#  '1993_1995',
#  '1996_1998',
#  '1999_2001',
#  '2002_2004',
#  '2005_2007',
#  '2008_2010',
#  '2011_2013',
#  '2014_2016',
#  '2017_2019']

# %% [markdown]
# ##### Loop through each_year and each_size to dermine a suitable size for input sample

# %%
Sample_size_acc = {}
size_list = list(np.arange(0.05,0.98,0.05)) + list(np.arange(0.98,0.99,0.005)) + list(np.arange(0.99,0.9999,0.003))

for year in year_name:
    for size in size_list[::-1]:
        
        # get the names of train and test
        train_name = f'Training_sample_{region_en}_{year}'
        test_name  = f'Grid_select_{region_en}_{year}'    
        
        # import traning sample
        train_sample = pd.read_csv(f'./Data/{train_name}.csv')
        train_sample = train_sample.drop(['system:index','.geo'],axis=1)
        # train_test split to reduce the the sample size
        X = train_sample.drop('Built',1)
        y = train_sample['Built']
        X_train, _, y_train, _ = train_test_split(X, y, test_size=size,random_state=42,stratify =y )
        
        # import testing sample
        test_sample = pd.read_csv(f'./Data/{test_name}.csv')
        test_sample = test_sample.drop(['system:index','.geo'],axis=1)
        # get the X,y value
        X_test = test_sample.drop('Built',1)
        y_test = test_sample['Built']        
        

        # perform the RF classification
        RF = RandomForestClassifier(n_estimators=100,n_jobs=-1)
        RF.fit(X_train,y_train)
        y_pred = RF.predict(X_test)

        # get the accuracy, here get two kinds of accuracy
        acc_test = accuracy_score(y_test,y_pred)

        # add results to the acc_dict
        Sample_size_acc[(region_en,year,f'{(1-size)*100:.2f}',)] = [acc_test]

        # print out the process
        print(f'Accuracy calculation of {train_name}_{(1-size)*100:.2f} finished!')
# Out:
# Accuracy calculation of Training_sample_zhongnan_1990_1992_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1990_1992_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1993_1995_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1996_1998_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_1999_2001_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2002_2004_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2005_2007_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2008_2010_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2011_2013_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2014_2016_95.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_0.10 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_0.40 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_0.70 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_1.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_1.50 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_2.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_5.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_10.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_15.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_20.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_25.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_30.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_35.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_40.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_45.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_50.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_55.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_60.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_65.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_70.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_75.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_80.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_85.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_90.00 finished!
# Accuracy calculation of Training_sample_zhongnan_2017_2019_95.00 finished!

# %%
# formating the result and put it into a datafram
Size_accuracy = pd.DataFrame(Sample_size_acc).T
Size_accuracy.reset_index(inplace=True)
Size_accuracy.columns = ['Region','Year','Sample_size','Accuracy']

Size_accuracy['Year'] = Size_accuracy['Year'].astype('category')
Size_accuracy.sort_values(['Year','Sample_size'],inplace=True)
Size_accuracy.reset_index(inplace=True,drop=True)

# save the datafram to disk
Size_accuracy.to_csv(f'./Result/Sample_size_acc_{region_en}.csv',index=False)
Size_accuracy = pd.read_csv(f'./Result/Sample_size_acc_{region_en}.csv')

# %% [markdown]
# ##### Observe that 50% of the sample is enought for classification

# %%
plt.figure(figsize=[16,8])
sns.lineplot(data=Size_accuracy,x='Sample_size',y='Accuracy')
# Out:
# C:\Users\wangj\Anaconda3\envs\ee_py3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# <AxesSubplot:xlabel='Sample_size', ylabel='Accuracy'>

# %% [markdown]
# ##### Compare all region's accuracy

# %%
All_accuracy = []

for region in ['dongbei','huadong','zhongnan','xinan','xibei','NCP']:
    
    df = pd.read_csv(f'./Result/Sample_size_acc_{region}.csv')    
    All_accuracy.append(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-f6efd6c3e558> in <module>
#       3 for region in ['dongbei','huadong','zhongnan','xinan','xibei','NCP']:
#       4
# ----> 5     df = pd.read_csv(f'./Result/Sample_size_acc_{region}.csv')
#       6     All_accuracy.append(df)
#
# ~\Anaconda3\envs\ee_py3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\Anaconda3\envs\ee_py3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\Anaconda3\envs\ee_py3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~\Anaconda3\envs\ee_py3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~\Anaconda3\envs\ee_py3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: './Result/Sample_size_acc_dongbei.csv'

# %%
# concat all accuracy into one df
All_accurac_df = pd.concat(All_accuracy,0)

# %%
plt.figure(figsize=(18,10))
sns.lineplot(data = All_accurac_df,x='Sample_size',y='Accuracy',hue='Region')
